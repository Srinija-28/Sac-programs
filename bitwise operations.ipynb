# %%
#10.BITWISE OPERATIONS
import numpy as np
arr1=np.array([9,12,4,2,10])
arr2=np.array([5,13,10,4,5])
print("bitwise AND operation ",np.bitwise_and(arr1,arr2))
print("bitwise OR operation ",np.bitwise_or(arr1,arr2))
print("bitwise XOR operation ",np.bitwise_xor(arr1,arr2))
# Out:
# bitwise AND operation  [ 1 12  0  0  0]
# bitwise OR operation  [13 13 14  6 15]
# bitwise XOR operation  [12  1 14  6 15]
