# %%
#12.PERFORMING THE FOLLOWING BOOLEAN FUNCTIONS
import numpy as np
arr=np.array([10,20,30,40,50])
print(arr)
print(np.all(arr))
print(np.any(arr))
print(np.where(arr>20))
# Out:
# [10 20 30 40 50]
# True
# True
# (array([2, 3, 4]),)
