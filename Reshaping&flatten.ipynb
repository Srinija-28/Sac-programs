# %%
#3.RESHAPING  & FLATTEN
import numpy as np
A=np.array([10,20,30,40,50])
#PRINTING ELEMENTS IN ARRAY
print("elements in A:",A)
#RESHAPING
print("reshape(5,1):",A.reshape(5,1))
#FLATTEN
print("flatten:",A.flatten("A"))
# Out:
# elements in A: [10 20 30 40 50]
# reshape(5,1): [[10]
#  [20]
#  [30]
#  [40]
#  [50]]
# flatten: [10 20 30 40 50]
